# %% [markdown]
# # 03 — ESN + HDC Readout Experiment
#
# **Ziel:** HDC-basiertes Readout implementieren und gegen die
# Ridge-Regression-Baseline vergleichen. Metriken: NRMSE,
# Trainingszeit, Speicherverbrauch.
